# %% [markdown]
# python3 -m venv .venv
#
# source .venv/bin/activate
#
# pip install -r requirements.txt
#
#
# ## TO DO:
# #### change regression.py file to run this for remaining friedman models
# python3 utils/run_all_regression_models.py --model dirichlet_horseshoe_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman_correlated && python3 utils/run_all_regression_models.py --model dirichlet_student_t_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman_correlated && python3 utils/run_all_regression_models.py --model beta_horseshoe_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman_correlated && python3 utils/run_all_regression_models.py --model beta_student_t_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman_correlated
#
# #### change regression.py file to run this for friedman
# python3 utils/run_all_regression_models.py --model dirichlet_horseshoe_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman && python3 utils/run_all_regression_models.py --model dirichlet_student_t_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman && python3 utils/run_all_regression_models.py --model beta_horseshoe_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman && python3 utils/run_all_regression_models.py --model beta_student_t_tanh_L2 --output_dir results/regression/single_layer/tanh/friedman
#
# #### run remaining Beta models for both Friedman uncorrelated + correlated
# python3 utils/run_all_regression_models.py --model beta_horseshoe_tanh --output_dir results/regression/single_layer/tanh/friedman_correlated && python3 utils/run_all_regression_models.py --model beta_student_t_tanh --output_dir results/regression/single_layer/tanh/friedman_correlated
#
# python3 utils/run_all_regression_models.py --model beta_horseshoe_tanh --output_dir results/regression/single_layer/tanh/friedman && python3 utils/run_all_regression_models.py --model beta_student_t_tanh --output_dir results/regression/single_layer/tanh/friedman
#
# #### Fix notebooks to be cleaner!
